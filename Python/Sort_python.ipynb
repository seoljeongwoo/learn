# %%
import random

# Bubble sort 구현
def bubble_sort(data):
    while True:
        Swapped = False
        for i in range(0, len(data)-1):
            if data[i] > data[i+1]:
                data[i] , data[i+1] = data[i+1] , data[i]
                Swapped = True
        
        if Swapped == False:
            break
    return data

def Selection_sort(data):
    
    for i in range(0, len(data)):
        index = i
        for j in range(i,len(data)):
            if data[j] < data[index]:
                index = j
        data[i] , data[index] = data[index] , data[i]
    
    return data
        
def insertion_sort(data):
    
    for i in range(1, len(data)):
        value = data[i]
        index = i
        while index>0 and value < data[index-1]:
            data[index] = data[index-1]
            index -= 1
        data[index] = value
    return data


def quick_sort(data):
    if len(data) <= 1:
        return data
    
    pivot = data[0]
    left , right = list(), list()
    for i in range(1, len(data)):
        if pivot > data[i]:
            left.append(data[i])
        else:
            right.append(data[i])
    
    return quick_sort(left) + [pivot] + quick_sort(right)

def merge(left, right):
    merged = list()
    
    left_point , right_point = 0 , 0
    while left_point < len(left) and right_point < len(right):
        if left[left_point] < right[right_point]:
            merged.append(left[left_point])
            left_point += 1
        else:
            merged.append(right[right_point])
            right_point += 1
    
    while left_point < len(left):
        merged.append(left[left_point])
        left_point += 1
    
    while right_point < len(right):
        merged.append(right[right_point])
        right_point += 1
    
    return merged
        
    
def merge_partition(data):
    
    if len(data) <=1 :
        return data
    
    mid = int(len(data)/2)
    left = merge_partition(data[:mid])
    right = merge_partition(data[mid:])
    return merge(left, right)
    

if __name__ == "__main__":
    data = random.sample(range(1000) , 30)
    print("Bubble Sort 결과확인")
    print(bubble_sort(data)) #Bubble Sort 결과확인
    data = random.sample(range(1000) , 30)
    print("Selection Sort 결과확인")
    print(Selection_sort(data))
    data = random.sample(range(10),5 )
    print(data)
    print("insertion Sort 결과확인")
    print(insertion_sort(data))
    data = random.sample(range(1000), 30)
    print("Quick Sort 결과확인")
    print(quick_sort(data))
    data = random.sample(range(1000) , 30)
    print("Merge Sort 결과확인")
    print(merge_partition(data))
# Out:
# Bubble Sort 결과확인
# [4, 19, 124, 138, 159, 180, 198, 207, 234, 244, 309, 334, 353, 361, 408, 497, 506, 697, 732, 757, 766, 778, 851, 896, 902, 934, 939, 973, 983, 986]
# Selection Sort 결과확인
# [6, 70, 164, 169, 174, 175, 187, 192, 246, 278, 293, 330, 463, 474, 486, 601, 656, 665, 684, 698, 729, 753, 807, 834, 836, 878, 918, 926, 948, 953]
# [4, 6, 0, 8, 1]
# insertion Sort 결과확인
# [0, 1, 4, 6, 8]
# Quick Sort 결과확인
# [26, 31, 69, 81, 97, 116, 130, 211, 246, 276, 287, 290, 296, 313, 431, 438, 462, 530, 589, 614, 624, 693, 707, 754, 756, 759, 789, 830, 845, 906]
# Merge Sort 결과확인
# [3, 35, 57, 65, 89, 200, 251, 286, 289, 301, 316, 348, 356, 386, 416, 438, 473, 513, 517, 522, 545, 619, 676, 691, 700, 722, 760, 764, 915, 945]
